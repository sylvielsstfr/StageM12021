# %% [markdown]
# # Computation of SMC diffuse Background
#
# https://notebook.community/obscode/bootcamp/MoreNotebooks/AstropySmorgasbord
#
#
# The first step is to find good images of the SMC
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS
# - creation date : June 22th 2021

# %%
from astroquery.ned import Ned
from astropy import coordinates
import astropy.units as u
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

import numpy as np

# %%
import matplotlib.ticker                         # here's where the formatter is


plt.rcParams["figure.figsize"] = (16,8)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
from scipy import ndimage, misc

# %%
from astropy.coordinates import Angle
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy import units as u

from matplotlib.transforms import Affine2D
from astropy.visualization.wcsaxes import WCSAxes

# %% [markdown]
# # Simbad

# %%
from astroquery.simbad import Simbad
result_table = Simbad.query_object("SMC")
result_table
# Out:
# <Table length=1>
# MAIN_ID      RA        DEC    ... COO_QUAL COO_WAVELENGTH     COO_BIBCODE
#           "h:m:s"    "d:m:s"  ...
#  object    str13      str13   ...   str1        str1             object
# -------- ---------- --------- ... -------- -------------- -------------------
# NAME SMC 00 52 38.0 -72 48 01 ...        D              O 2003A&A...412...45P

# %%
result_table["RA","DEC"]
# Out:
# <Table length=1>
#     RA        DEC
#  "h:m:s"    "d:m:s"
#   str13      str13
# ---------- ---------
# 00 52 38.0 -72 48 01

# %%
Angle(result_table["RA"][0],unit='hourangle')
# Out:
# <Angle 0.87722222 hourangle>

# %%
smc_ra=Angle(result_table["RA"][0],unit='hourangle').degree
smc_ra
# Out:
# 13.158333333333331

# %%
Angle(result_table["DEC"][0],unit='degree')
# Out:
# <Angle -72.80027778 deg>

# %%
smc_dec=Angle(result_table["DEC"][0],unit='degree').degree
smc_dec
# Out:
# -72.80027777777778

# %% [markdown]
# # Ned query

# %%
result_table = Ned.query_object("smc")
print(result_table)
# Out:
# No.      Object Name           RA     ... Diameter Points Associations
#                             degrees   ...
# --- ---------------------- ---------- ... --------------- ------------
#   1 Small Magellanic Cloud   13.18659 ...               3            0

# %%
print(result_table.keys())
# Out:
# ['No.', 'Object Name', 'RA', 'DEC', 'Type', 'Velocity', 'Redshift', 'Redshift Flag', 'Magnitude and Filter', 'Separation', 'References', 'Notes', 'Photometry Points', 'Positions', 'Redshift Points', 'Diameter Points', 'Associations']

# %%
result_table.show_in_notebook()
# Out:
# <i>Table length=1</i>
# <table id="table140243620942608-451540" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>No.</th><th>Object Name</th><th>RA</th><th>DEC</th><th>Type</th><th>Velocity</th><th>Redshift</th><th>Redshift Flag</th><th>Magnitude and Filter</th><th>Separation</th><th>References</th><th>Notes</th><th>Photometry Points</th><th>Positions</th><th>Redshift Points</th><th>Diameter Points</th><th>Associations</th></tr></thead>
# <thead><tr><th></th><th></th><th></th><th>degrees</th><th>degrees</th><th></th><th>km / s</th><th></th><th></th><th></th><th>arcmin</th><th></th><th></th><th></th><th></th><th></th><th></th><th></th></tr></thead>
# <tr><td>0</td><td>1</td><td>Small Magellanic Cloud</td><td>13.18659</td><td>-72.8286</td><td>G</td><td>158.0</td><td>0.000527</td><td></td><td>2.7</td><td>--</td><td>3559</td><td>9</td><td>56</td><td>13</td><td>5</td><td>3</td><td>0</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table140243620942608-451540').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table140243620942608-451540').dataTable({
#         order: [],
#         pageLength: 50,
#         lengthMenu: [[10, 25, 50, 100, 500, 1000, -1], [10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [0, 1, 3, 4, 6, 7, 10, 11, 12, 13, 14, 15, 16, 17], type: "optionalnum"}]
#     });
# });
# </script>

# %%
#result_table = Ned.query_region("lmc", radius=500 * u.arcmin)
#print(result_table)

# %%
from astropy import wcs
# Create a new WCS object.  The number of axes must be set
# from the start
w = wcs.WCS(naxis=2)

# Set up an "Airy's zenithal" projection
# Vector properties may be set with Python lists, or Numpy arrays
w.wcs.crpix = [-234.75, 8.3393]
w.wcs.cdelt = np.array([-0.066667, 0.066667])
w.wcs.crval = [0, -90]
w.wcs.ctype = ["RA---AIR", "DEC--AIR"]
w.wcs.set_pv([(2, 1, 45.0)])

# %% [markdown]
# ## SkyView

# %%
from astroquery.skyview import SkyView

# %%
SkyView.list_surveys()
# Out:
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}

# %%
#pflist = SkyView.get_images(position='lmc', survey=['SDSSr'],radius=10 * u.arcmin)

# %%
#pflist=SkyView.get_images(position='lmc', survey=the_survey,radius=600 * u.arcmin)

# %% [markdown]
# # Mellinger

# %%
the_survey=['Mellinger Red','Mellinger Green','Mellinger Blue','H-Alpha Comp']
the_survey_color=["r","g","b","y"]

# %%
pflist=SkyView.get_images(position='smc', survey=the_survey,radius=300 * u.arcmin)

# %%
NX=len(pflist)

# %%
all_headers=[]
all_images=[]
all_wcs=[]
for ext in np.arange(NX):
    pf = pflist[ext] # first element of the list, might need a loop if multiple images
    image = pf[0].data

    head = pf[0].header
    wcs = WCS(head)
    
    fig=plt.figure(figsize=(10,10))
    ax = fig.add_subplot(projection=wcs)
    #ax = plt.subplot(projection=wcs)
    im=ax.imshow(image, cmap='viridis', origin='lower')
    #ax.grid(color='white', ls='solid')
    ax.set_xlabel('Right Ascension (J2000)')
    ax.set_ylabel('Declination (J2000)')
    the_title="{}".format(the_survey[ext])
    ax.set_title(the_title)
    ax.grid(color="w")
    plt.colorbar(im, ax=ax)
    sky=SkyCoord(smc_ra*u.degree,smc_dec*u.degree)
    x,y=wcs.world_to_pixel(sky)
    ax.scatter([x],[y],marker="+",s=2000,color='r')
    plt.show()
    
    all_headers.append(head)
    all_images.append(image)
    all_wcs.append(wcs)
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Unfixable error: Unprintable string 'Reference:   PASP 121, 1180, 2009          \tSurvey web site.'; commentary cards may only contain printable ASCII characters [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Unfixable error: Unprintable string 'Reference:   PASP 121, 1180, 2009          \tSurvey web site.'; commentary cards may only contain printable ASCII characters [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Unfixable error: Unprintable string 'Reference:   PASP 121, 1180, 2009          \tSurvey web site.'; commentary cards may only contain printable ASCII characters [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]

# %%
#all_headers[0]

# %%
all_images[0].shape
# Out:
# (300, 300)

# %%
plt.imshow(all_images[0],origin="lower")
plt.grid()

# %%
rot_img = ndimage.rotate(all_images[0],-45, reshape=False)
plt.imshow(rot_img,origin="lower")
plt.grid()

rot_img.shape
# Out:
# (300, 300)

# %% [markdown]
# # Calcul du bruit de fond en fonction de la distance

# %% [markdown]
# ### Hypothese de symetrie circulaire

# %%
def GetCircle(image,wcs,ra0,dec0,RMIN,RMAX):
    """
    Extract a Circle in the image between RMIN and RMAX
    
    input arg:
     - image : input image
     - wcs   : wcs allowing to convert image pixel into world coordinate
     - ra0,dec0 : center of the image (assummed to be LMC center)
     - RMIN : all pixels r<RMIN are set to 0
     - RMAX : all pixels r>RMAX are set to 0
     
     output:
     - image with the ring
    
    """
    X=np.arange(image.shape[1])
    Y=np.arange(image.shape[0])
    
    xv, yv = np.meshgrid(X, Y)
    sky = wcs.pixel_to_world(xv, yv)
    sky_center=SkyCoord(ra0*u.deg,dec0*u.deg)
    
    sky_sep=sky.separation(sky_center)
    sky_sep_arcmin=sky_sep.arcmin
    
    
    new_image=np.where(np.logical_or(sky_sep_arcmin<RMIN,sky_sep_arcmin>=RMAX),0,image)
    
    return new_image

# %%
def GetDiffuseBackground_circ(the_image,the_wcs,lmc_ra,lmc_dec,rmin,rmax):
    """
    """
    NBINS=len(rmin)
    average_background=np.zeros(NBINS)
    
    for ibin in np.arange(NBINS):
    
        new_image=GetCircle(the_image,the_wcs,lmc_ra,lmc_dec,rmin[ibin],rmax[ibin])
        good_pixels=np.where(new_image>0) # do not average over empty pixels
        good_data=new_image[good_pixels]
        average_background[ibin]=np.median(good_data.ravel())
    return average_background

# %% [markdown]
# ## Hypothese par tranche

# %%
def GetSlice(image,RMIN,RMAX):
    """
    """
    
    X=np.arange(image.shape[1])
    Y=np.arange(image[0].shape[0])
    
    xv, yv = np.meshgrid(X, Y)
    
    new_image=np.where(np.logical_or(yv<RMIN,yv>=RMAX),0,image)
    return new_image

# %%
def GetSliceinWorld(image,wcs,ra0,dec0,RMIN,RMAX):
    """
    """
    
    X=np.arange(image.shape[1])
    Y=np.arange(image[0].shape[0])
    
    xv, yv = np.meshgrid(X, Y)
    
    sky = wcs.pixel_to_world(xv, yv)
    sky_center=SkyCoord(ra0*u.deg,dec0*u.deg)
    #dsky=sky-sky_center
    
    new_image=np.where(np.logical_or(sky.dec.arcmin<sky_center.dec.arcmin+RMIN,sky.dec.arcmin>=sky_center.dec.arcmin+RMAX),
                       0,image)
    
    
    
    return new_image

# %%
def GetDiffuseBackground_lin(the_image,the_wcs,smc_ra,smc_dec,rmin,rmax,rotangle=-45):
    """
    """
    NBINS=len(rmin)
    average_background=np.zeros(NBINS)
    
    for ibin in np.arange(NBINS):
            
        the_image_rot=ndimage.rotate(the_image,rotangle, reshape=False)
        new_image=GetSliceinWorld(the_image_rot,the_wcs,smc_ra,smc_dec,rmin[ibin],rmax[ibin])
        good_pixels=np.where(new_image>0) # do not average over empty pixels
        good_data=new_image[good_pixels]
        average_background[ibin]=np.median(good_data.ravel())
    return average_background

# %% [markdown]
# # Plot

# %%
idx=0
the_image=all_images[idx]
the_wcs=all_wcs[idx]

# %%
plt.imshow(GetCircle(the_image,the_wcs,smc_ra,smc_dec,50,100))

# %%
fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection=wcs)
  
im=ax.imshow(rot_img, cmap='viridis', origin='lower')
  
ax.set_xlabel('Right Ascension (J2000)')
ax.set_ylabel('Declination (J2000)')

ax.grid()

# %%
rot_img_cut=GetSliceinWorld(rot_img,the_wcs,smc_ra,smc_dec,-25,25)

# %%
fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection=wcs)
ax.imshow(rot_img_cut,origin="lower")
ax.grid()

# %% [markdown]
# # Diffuse Background

# %%
rmin=np.arange(0,290,10)
rmax=rmin+10
rav=(rmin+rmax)/2
NBINS=len(rmin)

# %%
fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111)

for ext in np.arange(NX-1):
    
    the_image=all_images[ext]
    the_wcs=all_wcs[ext]
    
    average_background=GetDiffuseBackground_circ(the_image,the_wcs,smc_ra,smc_dec,rmin,rmax)
    ax.plot(rav,2.5*np.log10(average_background/average_background[0]),"o-",color=the_survey_color[ext],label=the_survey[ext])
    
    
    
    ax.legend()
    ax.set_xlabel("R (arcmin)")
    ax.set_ylabel("Relative magnitude")
ax.set_title("SMC : Relative diffuse background in circular regions")
# Out:
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# Text(0.5, 1.0, 'SMC : Relative diffuse background in circular regions')

# %%
fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111)

for ext in np.arange(NX-1):
    
    the_image=all_images[ext]
    the_wcs=all_wcs[ext]
    
    average_background=GetDiffuseBackground_lin(the_image,the_wcs,smc_ra,smc_dec,rmin,rmax)
    ax.plot(rav,2.5*np.log10(average_background/average_background[0]),"o-",color=the_survey_color[ext],label=the_survey[ext]+" ,$\delta$>0")
    
    average_background=GetDiffuseBackground_lin(the_image,the_wcs,smc_ra,smc_dec,-rmax,rmin)
    ax.plot(rav,2.5*np.log10(average_background/average_background[0]),"o:",color=the_survey_color[ext],label=the_survey[ext]+" ,$\delta$<0")
    
    ax.legend()
    ax.set_xlabel("R (arcmin)")
    ax.set_ylabel("Relative magnitude")
ax.set_title("SMC : Relative diffuse background in bands regions")
# Out:
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# Text(0.5, 1.0, 'SMC : Relative diffuse background in bands regions')
